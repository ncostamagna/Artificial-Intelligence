# %% [markdown]
# <div style="text-align:center">
#     <h1>
#         Off-policy Monte Carlo Control
#     </h1>
# </div>
# <br>
#
# In this notebook we are going to implement the other of the two major strategies that exist when learning a policy by interacting with the environment, called off-policy learning. We will use two policies:
#
# - An exploratory policy called b.
#
# - A target policy that will learn from the experience collected by b, called $\pi$
#
# <br><br>
# <div style="text-align:center">
#     <b>This notebook belongs to section 4 of the course "Reinforcement Learning: beginner to master".</b>
#     <br><br>
#     <a href="https://www.udemy.com">Reinforcement Learning: beginner to master</a> (English)
#     <br>
#     <a href="https://www.udemy.com">Reinforcement Learning: de principiante a maestro</a> (Spanish)
# </div>
#
# <br>
#
# <table style="width:35%">
#   <tr style="background-color: transparent">
#     <td style="width: 45%">
#         <a target="_parent" href="https://www.evlabs.io" style="float: center">
#             <img src="img/evlabs-square.png" width="75"/>
#         </a>
#     </td>
#     <td valign="bottom">
#         <a target="_parent" href="https://www.youtube.com/channel/UCksRNSzWuMV5IfdrPlglqqw">
#             <img src="img/YouTube.png" width="35"/>
#         </a>
#     </td>
#     <td>
#         <a target="_parent" href="https://www.linkedin.com/company/evlabs">
#             <img src="img/LinkedIn.png" width="35"/>
#         </a>
#     </td>
#     <td>
#         <a target="_parent" href="https://twitter.com/evelabs">
#             <img src="img/Twitter.png" width="35"/>
#         </a>
#     </td>
#     <td>
#         <a target="_parent" href="https://github.com/escape-velocity-labs/">
#             <img src="img/GitHub.png" width="35"/>
#         </a>
#     </td>
#
#   </tr>
#   <tr style="background-color: transparent">
#     <th style="text-align: center; width: 70%">Escape Velocity Labs</th>
#   </tr>
#
# </table>
#
# <br>

# %% [markdown]
# ## Import the necessary software libraries:

# %%
import numpy as np
import matplotlib.pyplot as plt

from envs import Maze
from utils import plot_policy, plot_action_values, test_agent

# %% [markdown]
# ## Initialize the environment

# %%
env = Maze()

# %%
frame = env.render(mode='rgb_array')
plt.figure(figsize=(6, 6))
plt.axis('off')
plt.imshow(frame)

# %%
print(f"Observation space shape: {env.observation_space.nvec}")
print(f"Number of actions: {env.action_space.n}")
# Out:
# Observation space shape: [5 5]
# Number of actions: 4

# %% [markdown]
# ## Define value table $Q(s, a)$

# %% [markdown]
# #### Create the $Q(s, a)$ table

# %%
action_values = np.full((5, 5, 4), -100) # rellenamos todo con -100
action_values[4,4,:] = 0. # los valores de meta todos cero

# %% [markdown]
# #### Plot $Q(s, a)$

# %%
plot_action_values(action_values)

# %% [markdown]
# ## Define the target policy $\pi(s)$

# %% [markdown]
# #### Create the policy $\pi(s)$

# %%
def target_policy(state):
    av = action_values[state]
    
    return np.random.choice(np.flatnonzero(av == av.max())) # elegimos una de las que mas valor tienen al azar

# %% [markdown]
# #### Test the policy with state (0, 0)

# %%
action = target_policy((0,0))
print("accion tomada", {action}) # toma acualquiera al azar
# Out:
# accion tomada {3}

# %% [markdown]
# #### Plot the policy

# %%
plot_policy(action_values, frame)

# %% [markdown]
# ## Define the exploratory policy $b(s)$

# %% [markdown]
# #### Create the policy $b(s)$

# %%
def exploratory_policy(state, epsilon=0.):
    if np.random.random() < epsilon:
        return np.random.choice(4)
    else:
        av = action_values[state]
        return np.random.choice(np.flatnonzero(av == av.max()))

# %% [markdown]
# #### Test the policy with state (0, 0)

# %%
action = exploratory_policy((0,0), epsilon=0.5)
print("accion tomada", {action})
# Out:
# accion tomada {3}

# %% [markdown]
# ## Implement the algorithm
#
# ![Screenshot%202021-02-25%20at%2014.06.04.png](attachment:Screenshot%202021-02-25%20at%2014.06.04.png)
#
# </br>
#
#
#
# <div style="text-align:center">
#     Adapted from Barto & Sutton: "Reinforcement Learning: An Introduction".
# </div>

# %%
def off_policy_mc_control(action_values, target_policy, exploratory_policy, episodes, gamma=0.99, epsilon=0.2):
    
    csa = np.zeros((5,5,4))
    
    for episodes in range(1, episodes + 1):
        G = 0
        W = 1
        state = env.reset()
        done = False
        transitions = []
        
        while not done:
            action = exploratory_policy(state, epsilon)
            next_state, reward, done, _ = env.step(action)
            transitions.append([state, action, reward])
            state = next_state # la siguiente vez, este sera el nuevo estado, hasta que termine la tarea
            
        for state_t, action_t, reward_t in reversed(transitions):
            G = reward_t + gamma * G
            csa[state_t][action_t] += W # sumamos ratio importancia
            
            # actualizamos con una media ponderada a medida que obtenemos los retornos
            qsa = action_values[state_t][action_t] 
            action_values[state_t][action_t] += (W / csa[state_t][action_t]) * (G - qsa) 
            
            # ha tomado la acccion maximo con mayor valor q
            if action_t != target_policy(state_t):
                break 
                
            W = W * 1. / (1 - epsilon + epsilon / 4) # si escoje una accion es epsilon por las 4 opciones disponibles

# %%
off_policy_mc_control(action_values, target_policy, exploratory_policy, episodes=1000, epsilon=0.3)

# %% [markdown]
# ## Show results

# %% [markdown]
# #### Show resulting value table $Q(s, a)$

# %%
plot_action_values(action_values)
# no gastamos tiempo y esfuerzo en los lugares que no llegan a la meta

# %% [markdown]
# #### Show resulting policy $\pi(\cdot|s)$

# %%
plot_policy(action_values, frame)

# %% [markdown]
# #### Test the resulting agent

# %%
test_agent(env, target_policy)

# %% [markdown]
# ## Resources

# %% [markdown]
# [[1] Reinforcement Learning: An Introduction. Ch. 5: Monte Carlo methods](https://web.stanford.edu/class/psych209/Readings/SuttonBartoIPRLBook2ndEd.pdf)
